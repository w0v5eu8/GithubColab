# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #SSH Setting

# %%
# !mkdir -p ~/.ssh/
# !cp /content/drive/MyDrive/Colab/Git/GitHub_SSH/id_rsa ~/.ssh/
# !cp /content/drive/MyDrive/Colab/Git/GitHub_SSH/id_rsa.pub ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-babeld-ceb3dcb73
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %%
cd /content/drive/MyDrive/Colab/Git/GitHub
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab/Git/GitHub'
# /content

# %% [markdown]
# # Git Command

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'
# Out:
# fatal: --local can only be used inside a git repository
# fatal: --local can only be used inside a git repository

# %%
# Push
# after source files update,

# !git add .
# !git commit -m 'Commit'
# !git push
# Out:
# warning: adding embedded git repository: FNC/PK2
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> FNC/PK2
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached FNC/PK2
# hint:
# hint: See "git help submodule" for more information.
# [main cbb6a29] Commit
#  272 files changed, 269287 insertions(+), 48061 deletions(-)
#  delete mode 100644 Backup/FNC_KP1/README.md
#  delete mode 100644 Backup/FNC_KP1/data_collection/KRX_fullcode_1.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_collection/KRX_fullcode_2.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_collection/datacollection_1.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_collection/datacollection_2.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_preprocessing/AWS_sagemaker/AWS_preprocessing.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_preprocessing/AWS_sagemaker/preprocessing.py
#  delete mode 100644 Backup/FNC_KP1/data_preprocessing/TimeSeries_trend.ipynb
#  delete mode 100644 Backup/FNC_KP1/data_preprocessing/optimization.ipynb
#  delete mode 100644 Backup/FNC_KP1/modeling/ensemble.py
#  delete mode 100644 Backup/FNC_KP1/modeling/final_model_module.ipynb
#  create mode 100644 EEG_Common_Spatial_Pattern.ipynb
#  create mode 100644 EEG_Common_Spatial_Pattern_Demo.ipynb
#  create mode 100644 EEG_MNE_Demo1.ipynb
#  create mode 100644 EEG_MNE_Demo1_S1.csv
#  create mode 100644 EEG_MNE_Demo1_S2.csv
#  create mode 100644 EEG_MNE_Demo1_S3.csv
#  create mode 100644 EEG_MNE_Demo1_S4.csv
#  create mode 100644 EEG_MNE_Demo1_S5.csv
#  create mode 100644 EEG_MNE_Demo1_S6.csv
#  create mode 100644 EEG_MNE_Demo1_S7.csv
#  create mode 100644 EEG_MNE_Demo2.ipynb
#  create mode 100644 EEG_MNE_Demo2_S1.csv
#  create mode 100644 EEG_MNE_Demo2_S2.csv
#  rename BXAI/BXAI_ESN_AE_Pytocrh.py => ESN_AE_PyTocrh.py (100%)
#  rename BXAI/BXAI_Data_MackeyGlass_t17.txt => ESN_Data_MackeyGlass_t17.txt (100%)
#  rename BXAI/BXAI_ESN_Minimal.ipynb => ESN_Minimal.ipynb (100%)
#  rename BXAI/BXAI_ESN_pytorch.py => ESN_PyTorch.py (100%)
#  rename BXAI/BXAI_ESN_pytorch_Ex_MackeyGlass.ipynb => ESN_PyTorch_Usage_MackeyGlass.ipynb (100%)
#  rename BXAI/BXAI_ESN_pytorch_Ex_MackeyGlass_2readouts.ipynb => ESN_PyTorch_Usage_MackeyGlass_TwoReadouts.ipynb (100%)
#  create mode 100644 FNC/KN/AWS_Instance_List.txt
#  create mode 100644 FNC/KN/AWS_Readme.pdf
#  rename {Backup/FNC_KP2 => FNC/KN}/README.md (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_collection/KRX_fullcode_1.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_collection/KRX_fullcode_2.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_collection/datacollection_1.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_collection/datacollection_2.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_preprocessing/AWS_preprocessing.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_preprocessing/TimeSeries_trend.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_preprocessing/optimization.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_preprocessing/preprocessing.py (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/data_preprocessing/requirements.txt (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/modeling/ensemble.py (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/modeling/final.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/modeling/final_model_module.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/modeling/modeling_ML.ipynb (100%)
#  rename {Backup/FNC_KP2 => FNC/KN}/modeling/optimization_elasticnet.ipynb (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_00_Run.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_00_Run_E.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_01_ETF_Data.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_01_KOSPI_KOSDAQ_Data.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_01_KRX_Index_Data.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_01_SP500_yahoo_Data_Replace.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_02_Preprocessing.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Func_Extrema.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Func_PST.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Func_yahoo.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Temp_CC_Data.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Tool_Backtesting.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Tool_PST_Plot.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/FNC_Tool_codeNameFinder.m (100%)
#  rename {Backup/FNC_MATLAB => FNC/MATLAB1}/Temp.zip (100%)
#  create mode 100644 FNC/MATLAB2/Finance_00_Run.m
#  create mode 100644 FNC/MATLAB2/Finance_01_DATA_Init_fromNAVER.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA_NAVER.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA_NAVER_func_naver.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA_NAVER_func_naver_index.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA_func_google.m
#  create mode 100644 FNC/MATLAB2/Finance_02_DATA_func_yahoo.m
#  create mode 100644 FNC/MATLAB2/Finance_03_DATA_RemoveNaN.m
#  create mode 100644 FNC/MATLAB2/Finance_04_Adjust.m
#  create mode 100644 FNC/MATLAB2/Finance_05_PST.m
#  create mode 100644 FNC/MATLAB2/Finance_05_PST_func.m
#  create mode 100644 FNC/MATLAB2/Finance_05_PST_func_extrema.m
#  create mode 100644 FNC/MATLAB2/Finance_DATA_NaN_Check.m
#  create mode 100644 FNC/MATLAB2/Finance_PBR_Finder.m
#  create mode 100644 FNC/MATLAB2/Finance_PST_plot.m
#  create mode 100644 FNC/MATLAB2/Finance_PrintDate.m
#  create mode 100644 FNC/MATLAB2/Finnace_FindIndex.m
#  create mode 100644 FNC/MATLAB3/Untitled.m
#  create mode 100644 FNC/MATLAB3/code1/Simulation.m
#  create mode 100644 FNC/MATLAB3/code1/Simulation2.m
#  create mode 100644 FNC/MATLAB3/code1/generateNet.m
#  create mode 100644 FNC/MATLAB3/code1/generateTrainTestData.m
#  create mode 100644 FNC/MATLAB3/code1/generateTrainTestDataTentMap.m
#  create mode 100644 FNC/MATLAB3/code1/headers.m
#  create mode 100644 FNC/MATLAB3/code1/headers2.m
#  create mode 100644 FNC/MATLAB3/code1/headers3.m
#  create mode 100644 FNC/MATLAB3/code1/headersTentMap.m
#  create mode 100644 FNC/MATLAB3/code1/learnAndTest.m
#  create mode 100644 FNC/MATLAB3/code1/ma.m
#  create mode 100644 FNC/MATLAB3/code1/prv_ga_fit_SIM.m
#  create mode 100644 FNC/MATLAB3/code2/Simulation.m
#  create mode 100644 FNC/MATLAB3/code2/Simulation2.m
#  create mode 100644 FNC/MATLAB3/code2/Simulation3.m
#  create mode 100644 FNC/MATLAB3/code2/TA_header.m
#  create mode 100644 FNC/MATLAB3/code2/TA_oldbackup.m
#  create mode 100644 FNC/MATLAB3/code2/TA_s.m
#  create mode 100644 FNC/MATLAB3/code2/auto_esn.m
#  create mode 100644 FNC/MATLAB3/code2/auto_esn_s.m
#  create mode 100644 FNC/MATLAB3/code2/cccc.m
#  create mode 100644 FNC/MATLAB3/code2/cn_auto_esn2.m
#  create mode 100644 FNC/MATLAB3/code2/cn_sowhat.m
#  create mode 100644 FNC/MATLAB3/code2/continueRun.m
#  create mode 100644 FNC/MATLAB3/code2/createEmptyFigs.m
#  create mode 100644 FNC/MATLAB3/code2/f.m
#  create mode 100644 FNC/MATLAB3/code2/fInverse.m
#  create mode 100644 FNC/MATLAB3/code2/for_auto_esn_s.m
#  create mode 100644 FNC/MATLAB3/code2/generateNet.m
#  create mode 100644 FNC/MATLAB3/code2/generateTrainTestData.m
#  create mode 100644 FNC/MATLAB3/code2/headers.m
#  create mode 100644 FNC/MATLAB3/code2/headers2.m
#  create mode 100644 FNC/MATLAB3/code2/headers3.m
#  create mode 100644 FNC/MATLAB3/code2/learnAndTest.m
#  create mode 100644 FNC/MATLAB3/code2/master_head.m
#  create mode 100644 FNC/MATLAB3/code2/minusPoint5.m
#  create mode 100644 FNC/MATLAB3/code2/myeigs.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_CC1.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_CC2.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_CC3.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_CCI.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_DMI.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_ESN.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_MA.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_MFI.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_MTM.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_PL.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_PNVI.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_RC.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_RSI.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_SIM.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_SS.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_VR.m
#  create mode 100644 FNC/MATLAB3/code2/prv_ga_fit_WR.m
#  create mode 100644 FNC/MATLAB3/code2/reverseMat.m
#  create mode 100644 FNC/MATLAB3/code2/t2t_raw2pca.m
#  create mode 100644 FNC/MATLAB3/code2/ta_test.m
#  create mode 100644 FNC/MATLAB3/code2/temp_321.m
#  create mode 100644 FNC/MATLAB3/code2/temp_321end.m
#  create mode 100644 FNC/MATLAB3/code2/temp_rawch.m
#  create mode 100644 FNC/MATLAB3/code2/yss.m
#  create mode 100644 FNC/MATLAB3/code3/FindName.m
#  create mode 100644 FNC/MATLAB3/code3/S011_SetTarget.m
#  create mode 100644 FNC/MATLAB3/code3/S012_SetParameter.m
#  create mode 100644 FNC/MATLAB3/code3/S0_test_ESN.m
#  create mode 100644 FNC/MATLAB3/code3/S1_preESN.m
#  create mode 100644 FNC/MATLAB3/code3/S2_header.m
#  create mode 100644 FNC/MATLAB3/code3/S3_gen_net.m
#  create mode 100644 FNC/MATLAB3/code3/S4_gen_inout.asv
#  create mode 100644 FNC/MATLAB3/code3/S4_gen_inout.m
#  create mode 100644 FNC/MATLAB3/code3/S5_learning.m
#  create mode 100644 FNC/MATLAB3/code3/S6_results.m
#  create mode 100644 FNC/MATLAB3/code3/Simulation.m
#  create mode 100644 FNC/MATLAB3/code3/Simulation3.m
#  create mode 100644 FNC/MATLAB3/code3/TA_header.m
#  create mode 100644 FNC/MATLAB3/code3/TA_s.m
#  create mode 100644 FNC/MATLAB3/code3/auto_esn.m
#  create mode 100644 FNC/MATLAB3/code3/auto_esn_s.m
#  create mode 100644 FNC/MATLAB3/code3/cccc.m
#  create mode 100644 FNC/MATLAB3/code3/cn_auto_esn2.m
#  create mode 100644 FNC/MATLAB3/code3/cn_sowhat.m
#  create mode 100644 FNC/MATLAB3/code3/edit_raw_stock_p.m
#  create mode 100644 FNC/MATLAB3/code3/f.m
#  create mode 100644 FNC/MATLAB3/code3/fInverse.m
#  create mode 100644 FNC/MATLAB3/code3/for_auto_esn_s.m
#  create mode 100644 FNC/MATLAB3/code3/minusPoint5.m
#  create mode 100644 FNC/MATLAB3/code3/myeigs.m
#  create mode 100644 FNC/MATLAB3/code3/reverseMat.m
#  create mode 100644 FNC/MATLAB3/code3/t2t_raw2pca.m
#  create mode 100644 FNC/MATLAB3/code3/temp_rawch.m
#  create mode 100644 FNC/PK1/Fail/implemented(ga and backtest ), various exponents are being tried/preprocessing.ipynb
#  create mode 100644 "FNC/PK1/Fail/\341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245\341\204\217\341\205\263\341\204\205\341\205\251\341\206\257\341\204\205\341\205\265\341\206\274+\341\204\214\341\205\245\341\206\253\341\204\216\341\205\245\341\204\205\341\205\265(backtest, ga).ipynb"
#  create mode 100644 FNC/PK1/README.md
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/MDD.ipynb
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/_1.png
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/_2.png
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/_3.png
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/code.ipynb
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/hurst_exponenet_500.ipynb
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/hurst_exponent_500.txt
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/krx.ipynb
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/plt.ipynb
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/result .csv
#  create mode 100644 FNC/PK1/crawling _ hurst exponent/s_p500.ipynb
#  create mode 100644 FNC/PK1/data collect/data_collect_v1.ipynb
#  create mode 100644 FNC/PK1/data collect/data_collect_v2.ipynb
#  create mode 100644 FNC/PK1/data collect/data_collect_v3.ipynb
#  create mode 100644 FNC/PK1/mod_tradelogicv2_park3.ipynb
#  create mode 100644 FNC/PK1/module_analysis.ipynb
#  create mode 100644 FNC/PK1/module_v1.ipynb
#  create mode 100644 FNC/PK1/naver(Attempting to add variables such as per) .ipynb
#  create mode 100644 FNC/PK1/park3.ipynb
#  create mode 100644 FNC/PK1/trending/FNC_02_Preprocessing.py
#  create mode 100644 FNC/PK1/trending/FNC_Func_Extrema.py
#  create mode 100644 FNC/PK1/trending/FNC_Func_PST.py
#  create mode 100644 "FNC/PK1/\341\204\200\341\205\247\341\206\257\341\204\200\341\205\252\341\204\207\341\205\251\341\204\200\341\205\251\341\204\211\341\205\245.pdf"
#  create mode 100644 "FNC/PK1/\341\204\200\341\205\247\341\206\257\341\204\200\341\205\252\341\204\207\341\205\251\341\204\200\341\205\251\341\204\211\341\205\245\341\204\207\341\205\241\341\206\257\341\204\221\341\205\255\341\204\214\341\205\241\341\204\205\341\205\255.pdf"
#  create mode 160000 FNC/PK2
#  create mode 100644 FNC_FinanceDataReader_Demo.ipynb
#  create mode 100644 FNC_Hurst_Exponent.ipynb
#  create mode 100644 FNC_KRX_Crawling_Demo.ipynb
#  create mode 100644 FNC_TA-LIB_GeneticAlgorithm_Demo.ipynb
#  rename ML_00_Debugging_using_ChatGPT.ipynb => Lecture_ML_00_Debugging_using_ChatGPT.ipynb (100%)
#  rename ML_01-01_Linear_Regression.ipynb => Lecture_ML_01-01_Linear_Regression.ipynb (100%)
#  rename ML_01-02_Linear_Regression.ipynb => Lecture_ML_01-02_Linear_Regression.ipynb (100%)
#  rename ML_02_Logistic_Regression.ipynb => Lecture_ML_02_Logistic_Regression.ipynb (100%)
#  rename ML_03_KNN.ipynb => Lecture_ML_03_KNN.ipynb (100%)
#  rename ML_04_Naive_Bayes.ipynb => Lecture_ML_04_Naive_Bayes.ipynb (100%)
#  rename ML_05-01_Decision_Tree.ipynb => Lecture_ML_05-01_Decision_Tree.ipynb (100%)
#  rename ML_05-02_Decision_Tree.ipynb => Lecture_ML_05-02_Decision_Tree.ipynb (100%)
#  rename ML_06_Random_Forest.ipynb => Lecture_ML_06_Random_Forest.ipynb (100%)
#  create mode 100644 Lecture_ML_07-01_XGBoost.ipynb
#  rename ML_07-02_XGBoost.ipynb => Lecture_ML_07-02_XGBoost.ipynb (100%)
#  rename ML_08_LightGBM.ipynb => Lecture_ML_08_LightGBM.ipynb (100%)
#  rename ML_09-01_ML_Kmeans.ipynb => Lecture_ML_09-01_ML_Kmeans.ipynb (100%)
#  rename ML_09-02_KMeans.ipynb => Lecture_ML_09-02_KMeans.ipynb (100%)
#  rename ML_10-01_PCA.ipynb => Lecture_ML_10-01_PCA.ipynb (100%)
#  rename ML_10-02_PCA.ipynb => Lecture_ML_10-02_PCA.ipynb (100%)
#  rename ML_11_(Option)_SVM.ipynb => Lecture_ML_11_(Option)_SVM.ipynb (100%)
#  create mode 100644 Lecture_SKlearn_01_Classification_Regression.ipynb
#  create mode 100644 Lecture_SKlearn_02_SVM_DT_XGBOOST.ipynb
#  create mode 100644 Lecture_SKlearn_03_Clustering.ipynb
#  create mode 100644 Lecture_SKlearn_04_PCA.ipynb
#  create mode 100644 Lecture_TensorFlow_01_TensorFlow_DNN.ipynb
#  create mode 100644 Lecture_TensorFlow_02_TensorFlow_CNN.h5
#  create mode 100644 Lecture_TensorFlow_02_TensorFlow_CNN.ipynb
#  create mode 100644 Lecture_TensorFlow_03_TensorFlow_RNN_LSTM.ipynb
#  create mode 100644 Lecture_TensorFlow_03_TensorFlow_RNN_LSTM_BTC_USD_2019-02-28_2020-02-27.csv
#  create mode 100644 Lecture_TensorFlow_04_GenerativeModel.ipynb
#  create mode 100644 Lecture_XAI_01_Surrogate_Analysis.ipynb
#  create mode 100644 Lecture_XAI_02_Lecture_XAI_XGBoost_FI_PDP.ipynb
#  create mode 100644 Lecture_XAI_02_Lecture_XAI_XGBoost_FI_PDP_diabetes.csv
#  create mode 100644 Lecture_XAI_03_Lecture_XAI_LRP.ipynb
#  create mode 100644 Lecture_XAI_04_Lecture_XAI_CNN_FilterVisualization.ipynb
#  create mode 100644 Lecture_XAI_05_Lecture_XAI_CAM_GradCAM.ipynb
#  create mode 100644 Lecture_XAI_06_DT_CAM.ipynb
#  create mode 100644 Lecture_XAI_06_DT_CAM_hummingbird.jpg
#  delete mode 100644 ML_07-01_XGBoost.ipynb
#  create mode 100644 Optimization_DEAP_Genetic_Algorithm.ipynb
#  create mode 100644 PyTorch_Mini_Batch_Training.ipynb
#  create mode 100644 Python_Jupyter_Cell_to_PY.ipynb
#  create mode 100644 Pytorch_01-01_Python_Basics.ipynb
#  create mode 100644 Pytorch_01-02_Numpy_Basics.ipynb
#  create mode 100644 Pytorch_01-03_Linear_Classification.ipynb
#  create mode 100644 Pytorch_02-01_Pytorch_Tutorial.ipynb
#  create mode 100644 Pytorch_02-02_Deep_Neural_Network_(Pytorch).ipynb
#  create mode 100644 Pytorch_03-01_Convolutional_Neural_Network.ipynb
#  create mode 100644 Pytorch_03-02_Computer_Vision_Update.ipynb
#  create mode 100644 Pytorch_03-03_Generative_Adversarial_Network.ipynb
#  create mode 100644 Pytorch_04-01_Recurrent_Neural_Network.ipynb
#  create mode 100644 Pytorch_04-02_Word-level_Language_Modelling.ipynb
#  create mode 100644 Pytorch_04-03_Machine_Translation.ipynb
#  create mode 100644 Quantum_Computing_Basic.ipynb
#  create mode 100644 Quantum_Computing_Qiskit_Lecture_1.ipynb
#  create mode 100644 Quantum_Computing_Qiskit_Lecture_2.ipynb
#  create mode 100644 SNN_Izhikevich_Neuron_Model.ipynb
#  create mode 100644 SNN_Spike_Trian_Generator.ipynb
#  create mode 100644 SNN_Spiking_Neural_Network_for_MNIST.ipynb
#  create mode 100644 Sagemaker_CustomScripts_Demo1.ipynb
#  rename AWS/AWS_Sagemaker_CustomScript.ipynb => Sagemaker_CustomScripts_Demo2.ipynb (100%)
#  rename AWS/AWS_Sagemaker_CustomScript_Data_abalone.test => Sagemaker_CustomScripts_Demo_Data_abalone.test (100%)
#  rename AWS/AWS_Sagemaker_CustomScript_Data_abalone.train_0 => Sagemaker_CustomScripts_Demo_Data_abalone.train_0 (100%)
#  rename AWS/AWS_Sagemaker_CustomScript_Data_abalone.train_1 => Sagemaker_CustomScripts_Demo_Data_abalone.train_1 (100%)
#  rename AWS/AWS_Sagemaker_CustomScript_Data_abalone.validation => Sagemaker_CustomScripts_Demo_Data_abalone.validation (100%)
#  create mode 100644 Sagemaker_CustomScripts_Demo_Script1.py
#  create mode 100644 Sagemaker_CustomScripts_Demo_Script2.py
#  create mode 100644 Sagemaker_CustomScripts_Demo_Script3.py
#  create mode 100644 Sagemaker_CustomScripts_ESN.ipynb
#  create mode 100644 Sagemaker_CustomScripts_ESN_Data_MackeyGlass_t17.txt
#  rewrite [Git_Command].ipynb (98%)
#  create mode 100644 zMackey-Glass_Time_Series_to_Spike_Code.ipynb
# Enumerating objects: 244, done.
# Counting objects: 100% (244/244), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (236/236), done.
# Writing objects: 100% (242/242), 70.90 MiB | 6.58 MiB/s, done.
# Total 242 (delta 36), reused 37 (delta 4), pack-reused 0
# remote: Resolving deltas: 100% (36/36), completed with 1 local object.
# To github.com:w0v5eu8/GitHub.git
#    03c3ce1..cbb6a29  main -> main

# %%
# !git pull
# Out:
# Already up to date.
