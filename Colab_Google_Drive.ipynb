# %% [markdown]
# # Colab Google Drive

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !ls ../
# Out:
# bin	 datalab  home	 lib64	opt   run   sys		       tools
# boot	 dev	  lib	 media	proc  sbin  tensorflow-1.15.2  usr
# content  etc	  lib32  mnt	root  srv   tmp		       var

# %%
# !ls drive/
# Out:
# MyDrive  Shareddrives

# %%
# !ls drive/MyDrive
# Out:
# Archive  Code  Documents  KNU  MVB	Program  ScubaDiver  W
# Article  Data  GoodNotes  MVA  Picture	Scan	 T

# %%
# !ls drive/MyDrive/Code
# Out:
# 4N		Examples  GitHubSetting  GitTestDuplicate
# ColabWithR.txt	FNC	  GitTest	 Lecture

# %%
with open('/content/gdrive/My Drive/Colab Notebooks/Example_A.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/content/gdrive/My Drive/Colab Notebooks/Example_A.txt'
# Out:
# Hello Google Drive!

# %%
# !ls gdrive/MyDrive/'Colab Notebooks'
# Out:
# Example_A.txt  Example.txt  Lecture.ipynb  test.ipynb  Untitled0.ipynb

# %%
# !ls ..
# Out:
# bin	 datalab  home	 lib64	opt   run   sys		       tools
# boot	 dev	  lib	 media	proc  sbin  tensorflow-1.15.2  usr
# content  etc	  lib32  mnt	root  srv   tmp		       var

# %%
# !ls .. -all
# Out:
# total 104
# drwxr-xr-x   1 root root 4096 Apr 13 03:49 .
# drwxr-xr-x   1 root root 4096 Apr 13 03:49 ..
# drwxr-xr-x   1 root root 4096 Apr  7 13:27 bin
# drwxr-xr-x   2 root root 4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root 4096 Apr 13 04:01 content
# drwxr-xr-x   1 root root 4096 Apr  7 14:08 datalab
# drwxr-xr-x   5 root root  360 Apr 13 03:49 dev
# -rwxr-xr-x   1 root root    0 Apr 13 03:49 .dockerenv
# drwxr-xr-x   1 root root 4096 Apr 13 03:49 etc
# drwxr-xr-x   2 root root 4096 Apr 24  2018 home
# drwxr-xr-x   1 root root 4096 Apr  7 13:29 lib
# drwxr-xr-x   2 root root 4096 Apr  7 13:19 lib32
# drwxr-xr-x   1 root root 4096 Apr  7 13:19 lib64
# drwxr-xr-x   2 root root 4096 Sep 21  2020 media
# drwxr-xr-x   2 root root 4096 Sep 21  2020 mnt
# drwxr-xr-x   1 root root 4096 Apr  7 13:30 opt
# dr-xr-xr-x 121 root root    0 Apr 13 03:49 proc
# drwx------   1 root root 4096 Apr 13 03:50 root
# drwxr-xr-x   1 root root 4096 Apr  7 13:22 run
# ...

# %%
# !ls ../usr
# Out:
# bin  games  grte  include  lib	lib32  local  sbin  share  src

# %%
# !ls ../usr/src
# Out:
# fortran.c	  fortran_thunking.c	    linux-headers-4.15.0-140-generic
# fortran_common.h  fortran_thunking.h	    nvidia-460.67
# fortran.h	  linux-headers-4.15.0-140

# %%
# !ls ../usr/src -all
# Out:
# total 444
# drwxr-xr-x  1 root root   4096 Apr  7 13:29 .
# drwxr-xr-x  1 root root   4096 Apr  7 13:30 ..
# -rw-r--r--  1 root root  64667 Aug  9  2019 fortran.c
# -rw-r--r--  1 root root  17859 Aug  9  2019 fortran_common.h
# -rw-r--r--  1 root root  39040 Aug  9  2019 fortran.h
# -rw-r--r--  1 root root 269462 Aug  9  2019 fortran_thunking.c
# -rw-r--r--  1 root root  34362 Aug  9  2019 fortran_thunking.h
# drwxr-xr-x 25 root root   4096 Apr  7 13:29 linux-headers-4.15.0-140
# drwxr-xr-x  8 root root   4096 Apr  7 13:29 linux-headers-4.15.0-140-generic
# drwxr-xr-x  8 root root   4096 Apr  7 13:24 nvidia-460.67
