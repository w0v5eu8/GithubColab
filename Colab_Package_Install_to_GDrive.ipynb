# %% [markdown]
# # Colab Package Install to GDrive

# %% [markdown]
# ## Symbolic link 설정
#
# *   Colab Notebooks 경로의 space 가 있어서 그냥 pip하면 문제가 생김
# *   그래서 symbolic link 를 사용

# %%
# Goolge Drive 연결
import os, sys
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# symbolic link 설정
#
# ```
# # symbolic link 설정
# # 'Colab Notebooks' 루트 경로를 'SymLink_Colab_Notebooks'로 연결
# os.symlink('/content/drive/MyDrive/Colab Notebooks', '/content/drive/MyDrive/SymLink_Colab_Notebooks')
# ```

# %%
os.symlink('/content/drive/MyDrive/Colab Notebooks', '/content/drive/MyDrive/SymLink_Colab_Notebooks')

# %% [markdown]
# ## Packages 설치
# *   dependency 오류가 나는 것은 일단 정상임.
# *   패키지 import, running시 문제가 없는지는 확인해보기

# %%
# 프로젝트별로 폴더 구별
dev_name = 'Examples' # Dev Project Name: Test
# Colab Notebooks 폴더 아래에 외부 패키지가 설치될 External_Packages 폴더가 미리 존재 해야 함
pg_path = '/content/drive/MyDrive/SymLink_Colab_Notebooks/[Packages]/'+dev_name

# 앞에서 만든 symbolic link를 system path에 추가
sys.path.append(pg_path) #  systemp path에 추가 방법 1
# sys.path.insert(0, pg_path) #  systemp path에 추가 방법 2 (append는 sys.path 리스트 맨 아래에 추가 insert는 지정 인덱스에 삽입)

# %%
pg_path
# Out:
# '/content/drive/MyDrive/SymLink_Colab_Notebooks/[Packages]/Examples'

# %%
# package 설치
# !pip install --target=$pg_path MNE
#!pip install --target=$pg_path backtrader
#!pip install --target=$pg_path backtesting
#!pip install --target=$pg_path deap
#!pip install --target=$pg_path talib-binary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 67.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 33.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 73.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 62.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Package 사용
#
# 패키지를 사용하려면 아래 처럼 패키지가 설치된 경로를 symbolic link 경로로 sys.path에 추가하여야 함.
# ```
# # 프로젝트별로 폴더 구별
# dev_name = 'Test' # Dev Project Name: Test
# # Colab Notebooks 폴더 아래에 외부 패키지가 설치될 External_Packages 폴더가 미리 존재 해야 함
# pg_path = '/content/drive/MyDrive/SymLink_Colab_Notebooks/[Packages]/'+dev_name
#
# # 앞에서 만든 symbolic link를 system path에 추가
# sys.path.append(pg_path) #  systemp path에 추가 방법 1
# # sys.path.insert(0, pg_path) #  systemp path에 추가 방법 2 (append는 sys.path 리스트 맨 아래에 추가 insert는 지정 인덱스에 삽입
# ```
# 추가 하면 아래 코드 처럼 패키지 import 가능

# %%
import numpy
import talib

close = numpy.random.random(100)
output = talib.SMA(close)

print(close)
print(output)
# Out:
# [0.71830662 0.77721485 0.37715599 0.49310752 0.08913036 0.02341325
#  0.53750145 0.15625124 0.03490714 0.36379058 0.46487454 0.04628993
#  0.6930369  0.30431674 0.51013233 0.62598837 0.42297673 0.89551289
#  0.8821106  0.87460137 0.69562735 0.97364596 0.04633958 0.25492315
#  0.78010987 0.63537412 0.48490182 0.14383917 0.3027785  0.54930794
#  0.52891033 0.63140725 0.51799619 0.24158668 0.01576682 0.54300226
#  0.40948161 0.91967172 0.63024352 0.93122724 0.81133246 0.12033177
#  0.86900353 0.05039279 0.33641019 0.33728354 0.41689358 0.62017733
#  0.11793582 0.53288607 0.13621062 0.28263948 0.44888236 0.78759125
#  0.05533846 0.40764789 0.07011718 0.73729749 0.88391429 0.97508762
#  0.47443783 0.81596241 0.93192242 0.86159369 0.01734836 0.95368813
#  0.84373608 0.77724816 0.63375056 0.3138469  0.36087509 0.87883593
#  0.19418538 0.79438631 0.5918643  0.56095871 0.63990963 0.71614064
#  0.84788923 0.39358546 0.46491868 0.12001464 0.2066873  0.98234714
# ...
