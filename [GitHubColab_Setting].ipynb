# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Generating SSH Key
#
# 키를 만들어서 공개키를 GitHub에 등록했으면 다시 실하하면 안 됨.

# %%
# !ssh-keygen
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:EubwArMAx1Z4VJv2uShGjDs+ZqxgbCdcIojc4qdodYU root@e701c8314bb2
# The key's randomart image is:
# +---[RSA 3072]----+
# |...+o..          |
# |..+ .  o         |
# |..o.. B          |
# |+..* E + .       |
# |++oo+ = S        |
# |= ++ o o .       |
# |.O+o+ . .        |
# |=oXo .           |
# |+=..             |
# +----[SHA256]-----+

# %%
cd ~/.ssh/
# Out:
# /root/.ssh

# %%
# !ls
# Out:
# id_rsa	id_rsa.pub

# %%
# !cat id_rsa.pub
# Out:
# ssh-rsa ... root@e701c8314bb2

# %%
# !cp ~/.ssh/id_rsa /content/drive/MyDrive/Colab/Git/GitHub_SSH

# %%
# !cp ~/.ssh/id_rsa.pub /content/drive/MyDrive/Colab/Git/GitHub_SSH

# %% [markdown]
# 이후 GitHub에 공개키 등록하기

# %% [markdown]
# # SSH Setting

# %%
# !mkdir -p ~/.ssh/
# !cp /content/drive/MyDrive/Colab/Git/GitHub_SSH/id_rsa ~/.ssh/
# !cp /content/drive/MyDrive/Colab/Git/GitHub_SSH/id_rsa.pub ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-babeld-ceb3dcb73
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# #Git Cloning

# %%
cd /content/drive/MyDrive/Colab/Git/
# Out:
# /content/drive/MyDrive/Colab/Git

# %%
# !git clone git@github.com:w0v5eu8/GitHubColab.git
# Out:
# Cloning into 'SM_FNC'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.
